# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df["APPLICATION_TYPE"].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_type_counts[application_type_counts < 500].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df["CLASSIFICATION"].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_value_counts = application_df["CLASSIFICATION"].value_counts()
classification_value_counts[classification_value_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_value_counts[classification_value_counts < 1000].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
categorical_data = pd.get_dummies(application_df[["APPLICATION_TYPE", "AFFILIATION", "CLASSIFICATION", "USE_CASE", "ORGANIZATION", "STATUS", "INCOME_AMT", "SPECIAL_CONSIDERATIONS"]])
categorical_data.head()
# Out:
#    STATUS  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1                   False                  True                 False
# 1       1                   False                 False                 False
# 2       1                   False                 False                 False
# 3       1                   False                 False                 False
# 4       1                   False                 False                 False
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                False                False                False
# 1                 True                False                False
# 2                False                False                 True
# 3                 True                False                False
# 4                 True                False                False
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  APPLICATION_TYPE_T8  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                False                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 42 columns]

# %%
from sklearn.decomposition import PCA
# Split our preprocessed data into our features and target arrays
X = categorical_data
X["ASK_AMT"] = application_df["ASK_AMT"]
y = application_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# #apply principal component analysis
# pca = PCA(n_components=15)
# X_train_scaled = pca.fit_transform(X_train_scaled)
# X_test_scaled = pca.fit_transform(X_test_scaled)

# %%
# !pip install keras_tuner
from keras_tuner import HyperModel, Hyperband
import tensorflow as tf

class MyHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = tf.keras.models.Sequential()

        # Hyperparameter for the number of units in the first layer
        model.add(tf.keras.layers.Dense(
            units=hp.Int('units', min_value=32, max_value=512, step=32),
            activation='relu',
            input_shape=self.input_shape
        ))

        num_layers = hp.Int('num_layers', min_value=1, max_value=5)
        # Tune the number of hidden layers
        for i in range(1, num_layers):
            model.add(tf.keras.layers.Dropout(0.5))
            model.add(tf.keras.layers.Dense(
                units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=32),
                activation=hp.Choice(f'activation_{i}', values=['relu', 'sigmoid', 'tanh'])
            ))

        model.add(tf.keras.layers.Dropout(0.5))
        model.add(tf.keras.layers.Dense(units = 1, activation = "sigmoid"))
        lr_choice = hp.Choice("lr", values=['0.01', '0.001', '0.0001'])

        optimizer = tf.keras.optimizers.Adam(learning_rate=float(lr_choice))

        model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
        return model

hypermodel = MyHyperModel(input_shape=(43,))
tuner = Hyperband(
    hypermodel,
    max_epochs=50,
    objective='val_accuracy',
    hyperband_iterations=2,
    tuner_id='my_tuner_name'
)

tuner.search(X_train_scaled, y_train, epochs=30, validation_data=(X_test_scaled, y_test))
# Out:
# Trial 179 Complete [00h 04m 25s]
# val_accuracy: 0.7327113747596741
#
# Best val_accuracy So Far: 0.73399418592453
# Total elapsed time: 03h 25m 54s
#
# Search: Running Trial #180
#
# Value             |Best Value So Far |Hyperparameter
# 64                |384               |units
# 4                 |4                 |num_layers
# 0.01              |0.0001            |lr
# 128               |352               |units_1
# relu              |sigmoid           |activation_1
# 192               |448               |units_2
# relu              |tanh              |activation_2
# 128               |320               |units_3
# relu              |relu              |activation_3
# 192               |480               |units_4
# relu              |sigmoid           |activation_4
# 50                |6                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 0                 |2                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/50
# 804/804 [==============================] - 4s 4ms/step - loss: 0.2189 - accuracy: 0.6693 - val_loss: 0.1921 - val_accuracy: 0.7240
# Epoch 2/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1995 - accuracy: 0.7179 - val_loss: 0.1950 - val_accuracy: 0.7297
# Epoch 3/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1962 - accuracy: 0.7229 - val_loss: 0.1888 - val_accuracy: 0.7282
# Epoch 4/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1939 - accuracy: 0.7247 - val_loss: 0.1877 - val_accuracy: 0.7299
# Epoch 5/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1929 - accuracy: 0.7251 - val_loss: 0.1901 - val_accuracy: 0.7300
# Epoch 6/50
# 804/804 [==============================] - 4s 4ms/step - loss: 0.1924 - accuracy: 0.7257 - val_loss: 0.1882 - val_accuracy: 0.7283
# Epoch 7/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1916 - accuracy: 0.7268 - val_loss: 0.1878 - val_accuracy: 0.7296
# Epoch 8/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1907 - accuracy: 0.7281 - val_loss: 0.1895 - val_accuracy: 0.7282
# Epoch 9/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1914 - accuracy: 0.7289 - val_loss: 0.1893 - val_accuracy: 0.7314
# Epoch 10/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1906 - accuracy: 0.7289 - val_loss: 0.1869 - val_accuracy: 0.7291
# Epoch 11/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1903 - accuracy: 0.7268 - val_loss: 0.1870 - val_accuracy: 0.7289
# Epoch 12/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.1897 - accuracy: 0.7274 - val_loss: 0.1883 - val_accuracy: 0.7328
# Epoch 13/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1897 - accuracy: 0.7298 - val_loss: 0.1876 - val_accuracy: 0.7286
# Epoch 14/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1899 - accuracy: 0.7288 - val_loss: 0.1882 - val_accuracy: 0.7290
# Epoch 15/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1890 - accuracy: 0.7299 - val_loss: 0.1879 - val_accuracy: 0.7321
# Epoch 16/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1898 - accuracy: 0.7289 - val_loss: 0.1880 - val_accuracy: 0.7315
# Epoch 17/50
# 804/804 [==============================] - 4s 4ms/step - loss: 0.1884 - accuracy: 0.7283 - val_loss: 0.1897 - val_accuracy: 0.7242
# Epoch 18/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1897 - accuracy: 0.7268 - val_loss: 0.1880 - val_accuracy: 0.7286
# Epoch 19/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1892 - accuracy: 0.7283 - val_loss: 0.1890 - val_accuracy: 0.7299
# Epoch 20/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1891 - accuracy: 0.7286 - val_loss: 0.1872 - val_accuracy: 0.7297
# Epoch 21/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.1891 - accuracy: 0.7282 - val_loss: 0.1872 - val_accuracy: 0.7262
# Epoch 22/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1886 - accuracy: 0.7292 - val_loss: 0.1868 - val_accuracy: 0.7285
# Epoch 23/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1890 - accuracy: 0.7282 - val_loss: 0.1870 - val_accuracy: 0.7307
# Epoch 24/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1885 - accuracy: 0.7294 - val_loss: 0.1886 - val_accuracy: 0.7266
# Epoch 25/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.1890 - accuracy: 0.7278 - val_loss: 0.1877 - val_accuracy: 0.7306
# Epoch 26/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1887 - accuracy: 0.7289 - val_loss: 0.1866 - val_accuracy: 0.7279
# Epoch 27/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1886 - accuracy: 0.7270 - val_loss: 0.1868 - val_accuracy: 0.7275
# Epoch 28/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1880 - accuracy: 0.7287 - val_loss: 0.1865 - val_accuracy: 0.7294
# Epoch 29/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.1875 - accuracy: 0.7298 - val_loss: 0.1883 - val_accuracy: 0.7300
# Epoch 30/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1883 - accuracy: 0.7283 - val_loss: 0.1870 - val_accuracy: 0.7286
# Epoch 31/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1885 - accuracy: 0.7274 - val_loss: 0.1879 - val_accuracy: 0.7272
# Epoch 32/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1885 - accuracy: 0.7297 - val_loss: 0.1873 - val_accuracy: 0.7299
# Epoch 33/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1883 - accuracy: 0.7291 - val_loss: 0.1902 - val_accuracy: 0.7305
# Epoch 34/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1884 - accuracy: 0.7276 - val_loss: 0.1866 - val_accuracy: 0.7291
# Epoch 35/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1880 - accuracy: 0.7299 - val_loss: 0.1861 - val_accuracy: 0.7303
# Epoch 36/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1890 - accuracy: 0.7287 - val_loss: 0.1865 - val_accuracy: 0.7299
# Epoch 37/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1883 - accuracy: 0.7311 - val_loss: 0.1871 - val_accuracy: 0.7296
# Epoch 38/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1880 - accuracy: 0.7301 - val_loss: 0.1888 - val_accuracy: 0.7294
# Epoch 39/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.1883 - accuracy: 0.7264 - val_loss: 0.1882 - val_accuracy: 0.7221
# Epoch 40/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1879 - accuracy: 0.7280 - val_loss: 0.1884 - val_accuracy: 0.7305
# Epoch 41/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1877 - accuracy: 0.7313 - val_loss: 0.1870 - val_accuracy: 0.7299
# Epoch 42/50
# 339/804 [===========>..................] - ETA: 1s - loss: 0.1882 - accuracy: 0.7297

# %%
# use best params
best_model = tuner.get_best_models(2)[0]
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20

# %%
best_model.save("/drive/bestModel.h5")
